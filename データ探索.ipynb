# %%
import pandas as pd
url="http://archive.ics.uci.edu/ml/machine-learning-databases/00352/Online%20Retail.xlsx"
df=pd.read_excel(url)
df
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#                InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %%
import numpy as np
df_2=df[np.isfinite(df['CustomerID'])]
df_2
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#                InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %%
df_3=df_2[~df_2['InvoiceNo'].str.contains("C",na=False)]
df_3
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#                InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %%
a=df_3['CustomerID'].drop_duplicates()
a
# Out:
# 0         17850.0
# 9         13047.0
# 26        12583.0
# 46        13748.0
# 65        15100.0
#            ...
# 536969    13436.0
# 537255    15520.0
# 538064    13298.0
# 538812    14569.0
# 541768    12713.0
# Name: CustomerID, Length: 4339, dtype: float64

# %%
b=df_3['InvoiceNo'].drop_duplicates()
b
# Out:
# 0         536365
# 7         536366
# 9         536367
# 21        536368
# 25        536369
#            ...
# 541865    581583
# 541867    581584
# 541869    581585
# 541890    581586
# 541894    581587
# Name: InvoiceNo, Length: 18536, dtype: object

# %%
c=df_3['StockCode'].drop_duplicates()
c
# Out:
# 0         85123A
# 1          71053
# 2         84406B
# 3         84029G
# 4         84029E
#            ...
# 527065    90214U
# 527067    90214W
# 527069    90214Z
# 530382     90089
# 540421     23843
# Name: StockCode, Length: 3665, dtype: object

# %%
d=df_3['Description'].drop_duplicates()
d
# Out:
# 0          WHITE HANGING HEART T-LIGHT HOLDER
# 1                         WHITE METAL LANTERN
# 2              CREAM CUPID HEARTS COAT HANGER
# 3         KNITTED UNION FLAG HOT WATER BOTTLE
# 4              RED WOOLLY HOTTIE WHITE HEART.
#                          ...
# 527067              LETTER "W" BLING KEY RING
# 527069              LETTER "Z" BLING KEY RING
# 530382         PINK CRYSTAL SKULL PHONE CHARM
# 537621     CREAM HANGING HEART T-LIGHT HOLDER
# 540421            PAPER CRAFT , LITTLE BIRDIE
# Name: Description, Length: 3877, dtype: object

# %%
import matplotlib.pyplot as plt
import matplotlib as mpl
import seaborn as sns
sns.set()
# %matplotlib inline

# %%
df_3["z"]=df_3["Quantity"]*df_3["UnitPrice"]
df_3["z"]
# Out:
# C:\Users\motok\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# 0         15.30
# 1         20.34
# 2         22.00
# 3         20.34
# 4         20.34
#           ...
# 541904    10.20
# 541905    12.60
# 541906    16.60
# 541907    16.60
# 541908    14.85
# Name: z, Length: 397924, dtype: float64

# %%
df_3
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#                InvoiceDate  UnitPrice  CustomerID         Country      z
# ...

# %%
df_3.groupby('Country').sum().head().sort_values(by='z',ascending=False)
# Out:
#            Quantity  UnitPrice  CustomerID          z
# Country
# Australia     84209    3612.50  14758528.0  138521.31
# Belgium       23237    7372.85  25246701.0   41196.34
# Austria        4881    1693.90   4982601.0   10198.68
# Brazil          356     142.60    408608.0    1143.60
# Bahrain         260      78.95    210027.0     548.40

# %%
#Australia y=z x=InvoiceDate
df_4=df_3[df_3["Country"]=='Australia']
df_4
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 197       536389     22941         CHRISTMAS LIGHTS 10 REINDEER         6
# 198       536389     21622     VINTAGE UNION JACK CUSHION COVER         8
# 199       536389     21791   VINTAGE HEADS AND TAILS CARD GAME         12
# 200       536389    35004C      SET OF 3 COLOURED  FLYING DUCKS         6
# 201       536389    35004G           SET OF 3 GOLD FLYING DUCKS         4
# ...          ...       ...                                  ...       ...
# 497681    578459     22086      PAPER CHAIN KIT 50'S CHRISTMAS         20
# 497682    578459     22340           NOEL GARLAND PAINTED ZINC         24
# 497683    578459     22576  SWALLOW WOODEN CHRISTMAS DECORATION        20
# 497684    578459     22580         ADVENT CALENDAR GINGHAM SACK        12
# 497685    578459     22669                    RED BABY BUNTING         12
#
#                InvoiceDate  UnitPrice  CustomerID    Country      z
# ...

# %%
x=df_4["InvoiceDate"]
y=df_4["z"]
plt.bar(x,y,align='center',width=0.5)
plt.xlabel('InvoiceDate')
plt.ylabel('Score')
plt.grid(True)

# %%
df_5=df_3[df_3['Country']=='Austria']
df_5
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 34293     539330     37449   CERAMIC CAKE STAND + HANGING CAKES         8
# 34294     539330     37446   MINI CAKE STAND WITH HANGING CAKES         8
# 34295     539330     22962                JAM JAR WITH PINK LID        12
# 34296     539330     21428  SET3 BOOK BOX GREEN GINGHAM FLOWER          4
# 34297     539330     22113          GREY HEART HOT WATER BOTTLE         4
# ...          ...       ...                                  ...       ...
# 536964    581232   15056BL              EDWARDIAN PARASOL BLACK        24
# 536965    581232    15056P               EDWARDIAN PARASOL PINK        12
# 536966    581232     22059        CERAMIC STRAWBERRY DESIGN MUG        24
# 536967    581232     22646   CERAMIC STRAWBERRY CAKE MONEY BANK        36
# 536968    581232      POST                              POSTAGE         4
#
#                InvoiceDate  UnitPrice  CustomerID  Country       z
# ...

# %%
x=df_5["InvoiceDate"]
y=df_5["z"]
plt.bar(x,y,align='center',width=0.5)
plt.xlabel('InvoiceDate')
plt.ylabel('Score')
plt.grid(True)

# %%
df_6=df_3[df_3['Country']=='Bahrain']
df_6
# Out:
#        InvoiceNo StockCode                         Description  Quantity  \
# 181140    552449     22693  GROW A FLYTRAP OR SUNFLOWER IN TIN        24
# 181141    552449     23076          ICE CREAM SUNDAE LIP GLOSS        96
# 181142    552449     23077                 DOUGHNUT LIP GLOSS         60
# 181143    552449     22890  NOVELTY BISCUITS CAKE STAND 3 TIER         2
# 181144    552449     22649        STRAWBERRY FAIRY CAKE TEAPOT         8
# 181145    552449     22423            REGENCY CAKESTAND 3 TIER         2
# 181146    552449    85040A     S/4 PINK FLOWER CANDLES IN BOWL        12
# 181147    552449     22699    ROSES REGENCY TEACUP AND SAUCER          6
# 181148    552449     22697     GREEN REGENCY TEACUP AND SAUCER         6
# 181149    552449     22698      PINK REGENCY TEACUP AND SAUCER         6
# 181150    552449    72802A   ROSE SCENT CANDLE IN JEWELLED BOX         6
# 181151    552449    72802B  OCEAN SCENT CANDLE IN JEWELLED BOX         6
# ...

# %%
x=df_6["InvoiceDate"]
y=df_6["z"]
plt.bar(x,y,align='center',width=0.5)
plt.xlabel('InvoiceDate')
plt.ylabel('Score')
plt.grid(True)

# %%
df_7=df_3[df_3['Country']=='Belgium']
df_7
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 7279      537026     84375        SET OF 20 KIDS COOKIE CUTTERS        12
# 7280      537026     21217        RED RETROSPOT ROUND CAKE TINS         2
# 7281      537026     21212      PACK OF 72 RETROSPOT CAKE CASES       120
# 7282      537026     21977   PACK OF 60 PINK PAISLEY CAKE CASES       120
# 7283      537026     22417       PACK OF 60 SPACEBOY CAKE CASES       120
# ...          ...       ...                                  ...       ...
# 541194    581493     23204          CHARLOTTE BAG APPLES DESIGN        10
# 541195    581493     21108   FAIRY CAKE FLANNEL ASSORTED COLOUR        18
# 541196    581493     22252  BIRDCAGE DECORATION TEALIGHT HOLDER        12
# 541197    581493     22807         SET OF 6 T-LIGHTS TOADSTOOLS         6
# 541198    581493      POST                              POSTAGE         1
#
#                InvoiceDate  UnitPrice  CustomerID  Country      z
# ...

# %%
x=df_7["InvoiceDate"]
y=df_7["z"]
plt.bar(x,y,align='center',width=0.5)
plt.xlabel('InvoiceDate')
plt.ylabel('Score')
plt.grid(True)

# %%
df_8=df_3[df_3['Country']=='Brazil']
df_8
# Out:
#        InvoiceNo StockCode                         Description  Quantity  \
# 157299    550201     22423            REGENCY CAKESTAND 3 TIER        16
# 157300    550201     22699    ROSES REGENCY TEACUP AND SAUCER         24
# 157301    550201     22697     GREEN REGENCY TEACUP AND SAUCER        24
# 157302    550201     22698      PINK REGENCY TEACUP AND SAUCER        24
# 157303    550201     22366                    DOORMAT AIRMAIL         10
# 157304    550201     21430  SET/3 RED GINGHAM ROSE STORAGE BOX        24
# 157305    550201     22630                DOLLY GIRL LUNCH BOX        24
# 157306    550201     22662         LUNCH BAG DOLLY GIRL DESIGN        10
# 157307    550201     22629                 SPACEBOY LUNCH BOX         12
# 157308    550201     22382          LUNCH BAG SPACEBOY DESIGN         10
# 157309    550201   15056BL             EDWARDIAN PARASOL BLACK         3
# 157310    550201    15056P              EDWARDIAN PARASOL PINK         3
# ...

# %%
x=df_7["InvoiceDate"]
y=df_7["z"]
plt.bar(x,y,align='center',width=0.5)
plt.xlabel('InvoiceDate')
plt.ylabel('Score')
plt.grid(True)

# %%
h=df_4.groupby('Description').max().head().sort_values(by='z',ascending=False)
h
# Out:
#                                InvoiceNo StockCode  Quantity  \
# Description
#  DOLLY GIRL BEAKER                563614     23345       200
# 12 PENCIL SMALL TUBE WOODLAND     543989     20973       384
# 12 PENCILS TALL TUBE POSY         556917     20984       240
# 10 COLOUR SPACEBOY PEN            556917     22418        48
#  I LOVE LONDON MINI BACKPACK      568708     23391         4
#
#                                       InvoiceDate  UnitPrice  CustomerID  \
# Description
#  DOLLY GIRL BEAKER            2011-08-18 08:51:00       1.08     12415.0
# 12 PENCIL SMALL TUBE WOODLAND 2011-02-15 09:52:00       0.55     12415.0
# 12 PENCILS TALL TUBE POSY     2011-06-15 13:37:00       0.85     12434.0
# 10 COLOUR SPACEBOY PEN        2011-06-15 13:37:00       0.85     12415.0
#  I LOVE LONDON MINI BACKPACK  2011-09-28 15:41:00       4.15     12393.0
#
#                                  Country      z
# Description
#  DOLLY GIRL BEAKER             Australia  216.0
# ...

# %%
h['z']
label=['DOLLY GIRL BEAKER','12 PENCIL SMALL TUBE WOODLAND','12 PENCILS TALL TUBE POSY','10 COLOUR SPACEBOY PEN','I LOVE LONDON MINI BACKPACK']

# %%
plt.pie(h['z'],labels=label)
# Out:
# ([<matplotlib.patches.Wedge at 0x18fd54c1c08>,
# ...
#  [Text(0.373421250672104, 1.0346770363482907, 'DOLLY GIRL BEAKER'),
#   Text(-0.962950423187256, -0.5317203047500488, '12 PENCIL SMALL TUBE WOODLAND'),
#   Text(0.5517988713059389, -0.9515870982865899, '12 PENCILS TALL TUBE POSY'),
#   Text(1.0046291717087683, -0.44801811051759327, '10 COLOUR SPACEBOY PEN'),
#   Text(1.095133377635405, -0.10335804365829243, 'I LOVE LONDON MINI BACKPACK')])

# %%
i=df_5.groupby('Description').max().head().sort_values(by='z',ascending=False)
i
# Out:
#                                      InvoiceNo StockCode  Quantity  \
# Description
#  SPACEBOY BABY GIFT SET                 554132     23007         6
# 12 PENCILS SMALL TUBE RED RETROSPOT     543027     20975        48
# 12 PENCILS SMALL TUBE SKULL             543027     20974        24
#  DOLLY GIRL BEAKER                      562602     23345        12
# 3 PIECE SPACEBOY COOKIE CUTTER SET      576019     22964         6
#
#                                             InvoiceDate  UnitPrice  \
# Description
#  SPACEBOY BABY GIFT SET             2011-05-23 09:43:00      14.95
# 12 PENCILS SMALL TUBE RED RETROSPOT 2011-02-02 14:51:00       0.65
# 12 PENCILS SMALL TUBE SKULL         2011-02-02 14:51:00       0.65
#  DOLLY GIRL BEAKER                  2011-08-08 10:11:00       1.25
# 3 PIECE SPACEBOY COOKIE CUTTER SET  2011-11-13 14:31:00       2.10
#
#                                      CustomerID  Country     z
# Description
# ...

# %%
i['z']
label2=['SPACEBOY BABY GIFT SET','12 PENCILS SMALL TUBE RED RETROSPOT','12 PENCILS SMALL TUBE SKULL','DOLLY GIRL BEAKER','3 PIECE SPACEBOY COOKIE CUTTER SET']

# %%
plt.pie(i['z'],labels=label2)
# Out:
# ([<matplotlib.patches.Wedge at 0x18fd57a23c8>,
# ...
#  [Text(-0.16052449418335152, 1.088224189570871, 'SPACEBOY BABY GIFT SET'),
#   Text(-0.6921708738003167, -0.8549265941953766, '12 PENCILS SMALL TUBE RED RETROSPOT'),
#   Text(0.23508401415882552, -1.0745862023527817, '12 PENCILS SMALL TUBE SKULL'),
#   Text(0.7900046002449742, -0.7654363014593564, 'DOLLY GIRL BEAKER'),
#   Text(1.0681520971120408, -0.26277575503677875, '3 PIECE SPACEBOY COOKIE CUTTER SET')])

# %%
j=df_6.groupby('Description').max().head().sort_values(by='z',ascending=False)
j
# Out:
#                                     InvoiceNo StockCode  Quantity  \
# Description
# DOUGHNUT LIP GLOSS                     552449     23077        60
# GROW A FLYTRAP OR SUNFLOWER IN TIN     552449     22693        24
# CERAMIC CAKE STAND + HANGING CAKES     553900     37449         2
# CERAMIC CAKE BOWL + HANGING CAKES      553900     37450         6
# GREEN REGENCY TEACUP AND SAUCER        552449     22697         6
#
#                                            InvoiceDate  UnitPrice  CustomerID  \
# Description
# DOUGHNUT LIP GLOSS                 2011-05-09 13:49:00       1.25     12355.0
# GROW A FLYTRAP OR SUNFLOWER IN TIN 2011-05-09 13:49:00       1.25     12355.0
# CERAMIC CAKE STAND + HANGING CAKES 2011-05-19 17:47:00       9.95     12353.0
# CERAMIC CAKE BOWL + HANGING CAKES  2011-05-19 17:47:00       2.95     12353.0
# GREEN REGENCY TEACUP AND SAUCER    2011-05-09 13:49:00       2.95     12355.0
#
#                                     Country     z
# Description
# ...

# %%
j['z']
label2=['DOUGHNUT LIP GLOSS','GROW A FLYTRAP OR SUNFLOWER IN TIN','CERAMIC CAKE STAND + HANGING CAKES','CERAMIC CAKE BOWL + HANGING CAKES','GREEN REGENCY TEACUP AND SAUCER']

# %%
plt.pie(j['z'],labels=label2)
# Out:
# ([<matplotlib.patches.Wedge at 0x18fd743d5c8>,
# ...
#  [Text(0.11083544004875082, 1.0944018938348015, 'DOUGHNUT LIP GLOSS'),
#   Text(-1.0190295790838744, -0.414220613866744, 'GROW A FLYTRAP OR SUNFLOWER IN TIN'),
#   Text(-0.22582019282458002, -1.076571056880441, 'CERAMIC CAKE STAND + HANGING CAKES'),
#   Text(0.5562114576651894, -0.9490146544505862, 'CERAMIC CAKE BOWL + HANGING CAKES'),
#   Text(1.0344786810319195, -0.37397039787991304, 'GREEN REGENCY TEACUP AND SAUCER')])

# %%
k=df_7.groupby('Description').max().head().sort_values(by='z',ascending=False)
k
# Out:
#                                InvoiceNo StockCode  Quantity  \
# Description
#  SPACEBOY BABY GIFT SET           580965     23007         3
#  I LOVE LONDON MINI BACKPACK      580979     23391         4
# 12 PENCIL SMALL TUBE WOODLAND     539840     20973        24
#  DOLLY GIRL BEAKER                574862     23345        12
# 12 COLOURED PARTY BALLOONS        571187     22436        20
#
#                                       InvoiceDate  UnitPrice  CustomerID  \
# Description
#  SPACEBOY BABY GIFT SET       2011-12-06 14:52:00      16.95     12423.0
#  I LOVE LONDON MINI BACKPACK  2011-12-06 15:40:00       4.15     12362.0
# 12 PENCIL SMALL TUBE WOODLAND 2010-12-22 14:28:00       0.65     12383.0
#  DOLLY GIRL BEAKER            2011-11-07 12:27:00       1.25     12417.0
# 12 COLOURED PARTY BALLOONS    2011-10-14 11:39:00       0.65     12380.0
#
#                                Country      z
# Description
#  SPACEBOY BABY GIFT SET        Belgium  50.85
# ...

# %%
k['z']
label3=['SPACEBOY BABY GIFT SET','I LOVE LONDON MINI BACKPACK','12 PENCIL SMALL TUBE WOODLAND','DOLLY GIRL BEAKER','12 COLOURED PARTY BALLOONS']

# %%
plt.pie(k['z'],labels=label3)
# Out:
# ([<matplotlib.patches.Wedge at 0x18fd6b39308>,
# ...
#  [Text(0.14505696965248913, 1.0903937250164444, 'SPACEBOY BABY GIFT SET'),
#   Text(-1.076944267663439, -0.2240335786145885, 'I LOVE LONDON MINI BACKPACK'),
#   Text(-0.4831712505292044, -0.9882031889556141, '12 PENCIL SMALL TUBE WOODLAND'),
#   Text(0.4393890621187397, -1.0084330677295417, 'DOLLY GIRL BEAKER'),
#   Text(1.0264452301443348, -0.39548728110262155, '12 COLOURED PARTY BALLOONS')])

# %%
l=df_8.groupby('Description').max().head().sort_values(by='z',ascending=False)
l
# Out:
#                             InvoiceNo StockCode  Quantity         InvoiceDate  \
# Description
# DOORMAT AIRMAIL                550201     22366        10 2011-04-15 10:25:00
# DOLLY GIRL LUNCH BOX           550201     22630        24 2011-04-15 10:25:00
# COOK WITH WINE METAL SIGN      550201     21166        12 2011-04-15 10:25:00
# EDWARDIAN PARASOL BLACK        550201   15056BL         3 2011-04-15 10:25:00
# CLOCK MAGNET MUM'S KITCHEN     550201     23179         6 2011-04-15 10:25:00
#
#                             UnitPrice  CustomerID Country      z
# Description
# DOORMAT AIRMAIL                  6.75     12769.0  Brazil  67.50
# DOLLY GIRL LUNCH BOX             1.95     12769.0  Brazil  46.80
# COOK WITH WINE METAL SIGN        2.08     12769.0  Brazil  24.96
# EDWARDIAN PARASOL BLACK          5.95     12769.0  Brazil  17.85
# CLOCK MAGNET MUM'S KITCHEN       2.89     12769.0  Brazil  17.34

# %%
l['z']
label4=['DOORMAT AIRMAIL','DOLLY GIRL LUNCH BOX','COOK WITH WINE METAL SIGN','EDWARDIAN PARASOL BLACK','CLOCK MAGNET MUMS KITCHEN']

# %%
plt.pie(l['z'],labels=label4)
# Out:
# ([<matplotlib.patches.Wedge at 0x18fd9b1e408>,
# ...
#  [Text(0.3825751545112829, 1.0313274218940696, 'DOORMAT AIRMAIL'),
#   Text(-1.0903781410768758, -0.14517406607840463, 'DOLLY GIRL LUNCH BOX'),
#   Text(-0.16018224814734985, -1.0882746194681108, 'COOK WITH WINE METAL SIGN'),
#   Text(0.6434342972175993, -0.8921840085790007, 'EDWARDIAN PARASOL BLACK'),
#   Text(1.0468028850032831, -0.33794040887233817, 'CLOCK MAGNET MUMS KITCHEN')])
